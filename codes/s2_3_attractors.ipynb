# %%
import numpy as np
import pandas as pd

def logistic_curve(x, r):
    return r * x * (1 - x)

r_value = 2.5

# Values used to evaluate the rule
x_values = np.linspace(0, 1, 100)

# Initial value for iteration
x_it = 0.1

rows = []

for t, x_t in enumerate(x_values):

    # Apply the rule to x_t
    x_next = logistic_curve(x_t, r_value)

    # Apply the same rule to the iterated value
    x_it_next = logistic_curve(x_it, r_value)

    rows.append([t, x_t, x_next, x_it, x_it_next])

    # Output becomes the input for the next iteration
    x_it = x_it_next


df_iteration = pd.DataFrame(
    rows,
    columns=['t', 'x_t', 'x_next', 'x_it', 'x_it_next']
)


# Color the two processes
df_iteration.style \
    .set_properties(
        subset=['x_t', 'x_next'],
        **{'background-color': 'lightblue'}
    ) \
    .set_properties(
        subset=['x_it', 'x_it_next'],
        **{'background-color': 'lightyellow'}
    ) \
    .format(precision=4)
# Out:
# <style type="text/css">
# #T_4c8d2_row0_col1, #T_4c8d2_row0_col2, #T_4c8d2_row1_col1, #T_4c8d2_row1_col2, #T_4c8d2_row2_col1, #T_4c8d2_row2_col2, #T_4c8d2_row3_col1, #T_4c8d2_row3_col2, #T_4c8d2_row4_col1, #T_4c8d2_row4_col2, #T_4c8d2_row5_col1, #T_4c8d2_row5_col2, #T_4c8d2_row6_col1, #T_4c8d2_row6_col2, #T_4c8d2_row7_col1, #T_4c8d2_row7_col2, #T_4c8d2_row8_col1, #T_4c8d2_row8_col2, #T_4c8d2_row9_col1, #T_4c8d2_row9_col2, #T_4c8d2_row10_col1, #T_4c8d2_row10_col2, #T_4c8d2_row11_col1, #T_4c8d2_row11_col2, #T_4c8d2_row12_col1, #T_4c8d2_row12_col2, #T_4c8d2_row13_col1, #T_4c8d2_row13_col2, #T_4c8d2_row14_col1, #T_4c8d2_row14_col2, #T_4c8d2_row15_col1, #T_4c8d2_row15_col2, #T_4c8d2_row16_col1, #T_4c8d2_row16_col2, #T_4c8d2_row17_col1, #T_4c8d2_row17_col2, #T_4c8d2_row18_col1, #T_4c8d2_row18_col2, #T_4c8d2_row19_col1, #T_4c8d2_row19_col2, #T_4c8d2_row20_col1, #T_4c8d2_row20_col2, #T_4c8d2_row21_col1, #T_4c8d2_row21_col2, #T_4c8d2_row22_col1, #T_4c8d2_row22_col2, #T_4c8d2_row23_col1, #T_4c8d2_row23_col2, #T_4c8d2_row24_col1, #T_4c8d2_row24_col2, #T_4c8d2_row25_col1, #T_4c8d2_row25_col2, #T_4c8d2_row26_col1, #T_4c8d2_row26_col2, #T_4c8d2_row27_col1, #T_4c8d2_row27_col2, #T_4c8d2_row28_col1, #T_4c8d2_row28_col2, #T_4c8d2_row29_col1, #T_4c8d2_row29_col2, #T_4c8d2_row30_col1, #T_4c8d2_row30_col2, #T_4c8d2_row31_col1, #T_4c8d2_row31_col2, #T_4c8d2_row32_col
col3, #T_4c8d2_row78_col4, #T_4c8d2_row79_col3, #T_4c8d2_row79_col4, #T_4c8d2_row80_col3, #T_4c8d2_row80_col4, #T_4c8d2_row81_col3, #T_4c8d2_row81_col4, #T_4c8d2_row82_col3, #T_4c8d2_row82_col4, #T_4c8d2_row83_col3, #T_4c8d2_row83_col4, #T_4c8d2_row84_col3, #T_4c8d2_row84_col4, #T_4c8d2_row85_col3, #T_4c8d2_row85_col4, #T_4c8d2_row86_col3, #T_4c8d2_row86_col4, #T_4c8d2_row87_col3, #T_4c8d2_row87_col4, #T_4c8d2_row88_col3, #T_4c8d2_row88_col4, #T_4c8d2_row89_col3, #T_4c8d2_row89_col4, #T

# %%
# Detect when the system reaches the fixed-point attractor

df_plot = df_iteration.copy()

tolerance = 1e-6

# How much does the state change at each iteration?
df_plot['change'] = abs(
    df_plot['x_it_next'] - df_plot['x_it']
)

# Find the first t from which all later changes
# remain below the tolerance
t_attractor = None

for t in df_plot['t']:

    remaining = df_plot.loc[
        df_plot['t'] >= t,
        'change'
    ]

    if (remaining < tolerance).all():
        t_attractor = t
        break


# Identify the three stages
df_plot['stage'] = 'Transient'

df_plot.loc[
    df_plot['t'] == 0,
    'stage'
] = 'Initial condition'

df_plot.loc[
    df_plot['t'] >= t_attractor,
    'stage'
] = 'Attractor'


t_attractor
# Out:
# 18

# %%
df_plot[['t', 'x_it', 'x_it_next', 'change', 'stage']]
# Out:
#      t      x_it  x_it_next        change              stage
# 0    0  0.100000   0.225000  1.250000e-01  Initial condition
# 1    1  0.225000   0.435938  2.109375e-01          Transient
# 2    2  0.435938   0.614740  1.788025e-01          Transient
# 3    3  0.614740   0.592087  2.265315e-02          Transient
# 4    4  0.592087   0.603800  1.171320e-02          Transient
# ..  ..       ...        ...           ...                ...
# 95  95  0.600000   0.600000  1.110223e-16          Attractor
# 96  96  0.600000   0.600000  1.110223e-16          Attractor
# 97  97  0.600000   0.600000  1.110223e-16          Attractor
# 98  98  0.600000   0.600000  1.110223e-16          Attractor
# 99  99  0.600000   0.600000  1.110223e-16          Attractor
#
# [100 rows x 5 columns]

# %%
import altair as alt

chart = alt.Chart(df_plot).mark_point(
    filled=True,
    size=90
).encode(
    x=alt.X(
        't:Q',
        title='Iteration'
    ),
    y=alt.Y(
        'x_it:Q',
        title='x'
    ),
    color=alt.Color(
        'stage:N',
        title=None,
        scale=alt.Scale(
            domain=[
                'Initial condition',
                'Transient',
                'Attractor'
            ],
            range=[
                'black',
                'orange',
                'blue'
            ]
        )
    ),
    tooltip=[
        alt.Tooltip('t:Q', title='Iteration'),
        alt.Tooltip('x_it:Q', title='x', format='.6f'),
        alt.Tooltip('stage:N', title='Stage')
    ]
).properties(
    width=750,
    height=380,
    title='From Initial Condition to Attractor'
).interactive()

chart
# Out:
# alt.Chart(...)
